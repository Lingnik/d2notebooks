# %% [markdown]
# ### Python setup
#
# See `README.md` for python environment setup instructions on OSX using `pyenv` in VSCode.  If you've got another way of getting a modern, viable python environment, feel free to use it.
#
# Here are the versions that I'm using when running this notebook:

# %%
import platform
import psutil

print(platform.python_version())

memory_info = psutil.virtual_memory()
print(f"Total memory: {memory_info.total / (1024 ** 3):.2f} GB")
print(f"Available memory: {memory_info.available / (1024 ** 3):.2f} GB")
print(f"Used memory: {memory_info.used / (1024 ** 3):.2f} GB")
print(f"Memory percent: {memory_info.percent}%")
# Out:
# 3.12.2
# Total memory: 64.00 GB
# Available memory: 33.31 GB
# Used memory: 29.83 GB
# Memory percent: 48.0%

# %% [markdown]
# ### Generate a self-signed cert that we can use for the https redirect during the OAuth login
#
# You'll need to tell your browser to "trust" this cert after the redirect

# %%
import os
import subprocess
import shutil
from IPython import get_ipython

def generate_key():
    if shutil.which("openssl") is None:
        print("openssl is not found. Please install openssl and make sure it's on your system path. See: https://wiki.openssl.org/index.php/Binaries")
        return

    if os.path.isfile("key.pem"):
        print("key.pem already exists, not regenerating it. Delete it if you'd like to regenerate it.")
    else:
        command = 'openssl req -x509 -newkey rsa:4096 -keyout key.pem -out cert.pem -days 365 -nodes -subj "/C=US/ST=California/L=San Francisco/O=My Company/OU=My Division/CN=localhost"'
        process = subprocess.Popen(command, shell=True)
        process.wait()

generate_key()
# Out:
# key.pem already exists, not regenerating it. Delete it if you'd like to regenerate it.

# %% [markdown]
# ### API Key and Client ID
#
# You'll need an API Key and Client ID to interact with Bungie's API.  You can generate one on Bungie's website: https://www.bungie.net/en/Application
#
# You can generate an application with the "Public" OAuth type with a redirect url of: `https://localhost:7777/oauth-redirect`  - this will be used after the oauth login to get the oauth token that will be used in API requests
#
# The only scope necessary is read access: `Read your Destiny 2 information (Vault, Inventory, and Vendors), as well as Destiny 1 Vault and Inventory data`
#
# This is what it should look like:
#
# ![Image](images/oauth-app-settings.png)
#
#
# Once you create your application, you should get an `OAuth client_id` and an `API Key`, values for these should be put into `config.json` along with your Bungie `username` (Steam usernames will have a 4-digit hash like `#1234` on the end).  It should look like this:
#
# ```
# { "client_id": "your_client_id", "api_key": "your_api_key", "username": "your_username#1234"}
# ```
#
# This same username is used on things like https://dungeon.report to find your user.
#
# This next cell will read that file in and make the `client_id`, `api_key`, and `username` values available to the rest of the calls.

# %%
from src import config

client_id, api_key, username = config.load_config()

print(f"client_id length: {len(client_id)}")
print(f"api_key length: {len(api_key)}")
print(f"username: {username}")
# Out:
# client_id length: 5
# api_key length: 32
# username: Dera#9169

# %% [markdown]
# ### Login with OAuth to get a token that'll last for 1 hour

# %%
from src.bungie_oauth import BungieAuth
import datetime

# perform oauth login to get the access token used in later requests.  It is good for 1 hour
print("We're using a self-signed certificate to run an HTTPS server on localhost, you'll need to accept the certificate in your browser.")
access_token = BungieAuth(client_id).refresh_oauth_token()

# token is good for 1 hour, print out the time that it expires
expiration_time = datetime.datetime.now() + datetime.timedelta(hours=1)
print(f"Access token successfully acquired at: {datetime.datetime.now().isoformat()} and expires at: {expiration_time.isoformat()}")
# Out:
# We're using a self-signed certificate to run an HTTPS server on localhost, you'll need to accept the certificate in your browser.
# Please go to the following URL and authorize the app: https://www.bungie.net/en/oauth/authorize?client_id=47118&response_type=code&state=rmQr13l7FAvGgasgdhi0zKpxJUI7QZFvo7Z7ak9TnOlxlYb1DtVhf_6NYeqVRqYRrd8mNRQdiILH_cTdS3y9ZYzzg5DgoX7v2zXPuDpTfRuyw75JqG-pP5P0inJDs4sMXKv_mp3tO_X0zgHSOjGxKegiGHa_bZqq5wLMD9N8jqI=&redirect_uri=https://localhost:7777/
# Stopping HTTPS server
# Access token successfully acquired at: 2024-06-13T08:07:38.550028 and expires at: 2024-06-13T09:07:38.549980

# %% [markdown]
# ### Now we're ready to talk to Bungie's API

# %%
from src.bungie_api import BungieApi

api = BungieApi(api_key, access_token)

membership_id, profile_type = api.get_primary_membership_id_and_type(username)
print(f"Membership ID: {membership_id}, Profile Type: {profile_type}")

api.get_character_ids_and_classes(membership_id, profile_type)
# Out:
# Checking membership ID 4611686018465007625 with membership type 2
# Crosave override found for 4611686018465007625
# Membership ID: 4611686018465007625, Profile Type: 2
# {'2305843009262309873': 'Warlock',
#  '2305843009262309875': 'Titan',
#  '2305843009716994332': 'Hunter'}

# %%
# retrieve the manifest and item/stat definitions that will be joined with profile data to determine what armor you have in your vault
item_definitions, stat_definitions = api.get_static_definitions()

# %%
manifest = api.get_manifest()
from pprint import pprint

world_component_content_paths = manifest['Response']['jsonWorldComponentContentPaths']['en']
print("jsonWorldComponentContentPaths:")
for key, value in world_component_content_paths.items():
    print(f"  {key}: {value}")

world_content_paths = manifest['Response']['jsonWorldContentPaths']['en']
print(f"jsonWorldContentPaths: {world_content_paths}")

mobile_asset_content_path = manifest['Response']['mobileAssetContentPath']
print(f"mobileAssetContentPath: {mobile_asset_content_path}")

mobile_gear_asset_data_bases = manifest['Response']['mobileGearAssetDataBases']
print(f"mobileGearAssetDataBases:")
for db in mobile_gear_asset_data_bases:
    print(f"  {db['version']}: {db['path']}")

mobile_world_content_paths = manifest['Response']['mobileWorldContentPaths']['en']
print(f"mobileWorldContentPaths: {mobile_world_content_paths}")
# Out:
# jsonWorldComponentContentPaths:
#   DestinyNodeStepSummaryDefinition: /common/destiny2_content/json/en/DestinyNodeStepSummaryDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyArtDyeChannelDefinition: /common/destiny2_content/json/en/DestinyArtDyeChannelDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyArtDyeReferenceDefinition: /common/destiny2_content/json/en/DestinyArtDyeReferenceDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyPlaceDefinition: /common/destiny2_content/json/en/DestinyPlaceDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyActivityDefinition: /common/destiny2_content/json/en/DestinyActivityDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyActivityTypeDefinition: /common/destiny2_content/json/en/DestinyActivityTypeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyClassDefinition: /common/destiny2_content/json/en/DestinyClassDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyGenderDefinition: /common/destiny2_content/json/en/DestinyGenderDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyInventoryBucketDefinition: /common/destiny2_content/json/en/DestinyInventoryBucketDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyRaceDefinition: /common/destiny2_content/json/en/DestinyRaceDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyTalentGridDefinition: /common/destiny2_content/json/en/DestinyTalentGridDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyUnlockDefinition: /common/destiny2_content/json/en/DestinyUnlockDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyStatGroupDefinition: /common/destiny2_content/json/en/DestinyStatGroupDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyProgressionMappingDefinition: /common/destiny2_content/json/en/DestinyProgressionMappingDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyFactionDefinition: /common/destiny2_content/json/en/DestinyFactionDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyVendorGroupDefinition: /common/destiny2_content/json/en/DestinyVendorGroupDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyRewardSourceDefinition: /common/destiny2_content/json/en/DestinyRewardSourceDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyUnlockValueDefinition: /common/destiny2_content/json/en/DestinyUnlockValueDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyRewardMappingDefinition: /common/destiny2_content/json/en/DestinyRewardMappingDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyRewardSheetDefinition: /common/destiny2_content/json/en/DestinyRewardSheetDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyItemCategoryDefinition: /common/destiny2_content/json/en/DestinyItemCategoryDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyDamageTypeDefinition: /common/destiny2_content/json/en/DestinyDamageTypeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyActivityModeDefinition: /common/destiny2_content/json/en/DestinyActivityModeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyMedalTierDefinition: /common/destiny2_content/json/en/DestinyMedalTierDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyAchievementDefinition: /common/destiny2_content/json/en/DestinyAchievementDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyActivityGraphDefinition: /common/destiny2_content/json/en/DestinyActivityGraphDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyActivityInteractableDefinition: /common/destiny2_content/json/en/DestinyActivityInteractableDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyBondDefinition: /common/destiny2_content/json/en/DestinyBondDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyCharacterCustomizationCategoryDefinition: /common/destiny2_content/json/en/DestinyCharacterCustomizationCategoryDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyCharacterCustomizationOptionDefinition: /common/destiny2_content/json/en/DestinyCharacterCustomizationOptionDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyCollectibleDefinition: /common/destiny2_content/json/en/DestinyCollectibleDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyDestinationDefinition: /common/destiny2_content/json/en/DestinyDestinationDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyEntitlementOfferDefinition: /common/destiny2_content/json/en/DestinyEntitlementOfferDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyEquipmentSlotDefinition: /common/destiny2_content/json/en/DestinyEquipmentSlotDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyEventCardDefinition: /common/destiny2_content/json/en/DestinyEventCardDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyFireteamFinderActivityGraphDefinition: /common/destiny2_content/json/en/DestinyFireteamFinderActivityGraphDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyFireteamFinderActivitySetDefinition: /common/destiny2_content/json/en/DestinyFireteamFinderActivitySetDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyFireteamFinderLabelDefinition: /common/destiny2_content/json/en/DestinyFireteamFinderLabelDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyFireteamFinderLabelGroupDefinition: /common/destiny2_content/json/en/DestinyFireteamFinderLabelGroupDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyFireteamFinderOptionDefinition: /common/destiny2_content/json/en/DestinyFireteamFinderOptionDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyFireteamFinderOptionGroupDefinition: /common/destiny2_content/json/en/DestinyFireteamFinderOptionGroupDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyStatDefinition: /common/destiny2_content/json/en/DestinyStatDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyInventoryItemDefinition: /common/destiny2_content/json/en/DestinyInventoryItemDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyInventoryItemLiteDefinition: /common/destiny2_content/json/en/DestinyInventoryItemLiteDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyItemTierTypeDefinition: /common/destiny2_content/json/en/DestinyItemTierTypeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyLoadoutColorDefinition: /common/destiny2_content/json/en/DestinyLoadoutColorDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyLoadoutIconDefinition: /common/destiny2_content/json/en/DestinyLoadoutIconDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyLoadoutNameDefinition: /common/destiny2_content/json/en/DestinyLoadoutNameDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyLocationDefinition: /common/destiny2_content/json/en/DestinyLocationDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyLoreDefinition: /common/destiny2_content/json/en/DestinyLoreDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyMaterialRequirementSetDefinition: /common/destiny2_content/json/en/DestinyMaterialRequirementSetDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyMetricDefinition: /common/destiny2_content/json/en/DestinyMetricDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyObjectiveDefinition: /common/destiny2_content/json/en/DestinyObjectiveDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinySandboxPerkDefinition: /common/destiny2_content/json/en/DestinySandboxPerkDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyPlatformBucketMappingDefinition: /common/destiny2_content/json/en/DestinyPlatformBucketMappingDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyPlugSetDefinition: /common/destiny2_content/json/en/DestinyPlugSetDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyPowerCapDefinition: /common/destiny2_content/json/en/DestinyPowerCapDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyPresentationNodeDefinition: /common/destiny2_content/json/en/DestinyPresentationNodeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyProgressionDefinition: /common/destiny2_content/json/en/DestinyProgressionDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyProgressionLevelRequirementDefinition: /common/destiny2_content/json/en/DestinyProgressionLevelRequirementDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyRecordDefinition: /common/destiny2_content/json/en/DestinyRecordDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyRewardAdjusterPointerDefinition: /common/destiny2_content/json/en/DestinyRewardAdjusterPointerDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyRewardAdjusterProgressionMapDefinition: /common/destiny2_content/json/en/DestinyRewardAdjusterProgressionMapDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyRewardItemListDefinition: /common/destiny2_content/json/en/DestinyRewardItemListDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinySackRewardItemListDefinition: /common/destiny2_content/json/en/DestinySackRewardItemListDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinySandboxPatternDefinition: /common/destiny2_content/json/en/DestinySandboxPatternDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinySeasonDefinition: /common/destiny2_content/json/en/DestinySeasonDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinySeasonPassDefinition: /common/destiny2_content/json/en/DestinySeasonPassDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinySocialCommendationDefinition: /common/destiny2_content/json/en/DestinySocialCommendationDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinySocketCategoryDefinition: /common/destiny2_content/json/en/DestinySocketCategoryDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinySocketTypeDefinition: /common/destiny2_content/json/en/DestinySocketTypeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyTraitDefinition: /common/destiny2_content/json/en/DestinyTraitDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyUnlockCountMappingDefinition: /common/destiny2_content/json/en/DestinyUnlockCountMappingDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyUnlockEventDefinition: /common/destiny2_content/json/en/DestinyUnlockEventDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyUnlockExpressionMappingDefinition: /common/destiny2_content/json/en/DestinyUnlockExpressionMappingDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyVendorDefinition: /common/destiny2_content/json/en/DestinyVendorDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyMilestoneDefinition: /common/destiny2_content/json/en/DestinyMilestoneDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyActivityModifierDefinition: /common/destiny2_content/json/en/DestinyActivityModifierDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyReportReasonCategoryDefinition: /common/destiny2_content/json/en/DestinyReportReasonCategoryDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyArtifactDefinition: /common/destiny2_content/json/en/DestinyArtifactDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyBreakerTypeDefinition: /common/destiny2_content/json/en/DestinyBreakerTypeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyChecklistDefinition: /common/destiny2_content/json/en/DestinyChecklistDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyEnergyTypeDefinition: /common/destiny2_content/json/en/DestinyEnergyTypeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinySocialCommendationNodeDefinition: /common/destiny2_content/json/en/DestinySocialCommendationNodeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyGuardianRankDefinition: /common/destiny2_content/json/en/DestinyGuardianRankDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyGuardianRankConstantsDefinition: /common/destiny2_content/json/en/DestinyGuardianRankConstantsDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyLoadoutConstantsDefinition: /common/destiny2_content/json/en/DestinyLoadoutConstantsDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
#   DestinyFireteamFinderConstantsDefinition: /common/destiny2_content/json/en/DestinyFireteamFinderConstantsDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
# jsonWorldContentPaths: /common/destiny2_content/json/en/aggregate-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json
# mobileAssetContentPath: /common/destiny2_content/sqlite/asset/asset_sql_content_9cc6678a20871e8f00a97d6f375383e5.content
# mobileGearAssetDataBases:
#   0: /common/destiny2_content/sqlite/asset/asset_sql_content_9cc6678a20871e8f00a97d6f375383e5.content
#   1: /common/destiny2_content/sqlite/asset/asset_sql_content_f02ae574a0bb7239607788b4de5ea7d4.content
#   2: /common/destiny2_content/sqlite/asset/asset_sql_content_f02ae574a0bb7239607788b4de5ea7d4.content
# mobileWorldContentPaths: /common/destiny2_content/sqlite/en/world_sql_content_abf97b217375515297e3c59205815b37.content

# %%
# download the character profile for this membership_id
import os
import json

# access_token, profile_type, and membership_id should be retrieved above 
# using the login_and_get_token and get_primary_membership_id_and_type functions

# https://bungie-net.github.io/multi/schema_Destiny-DestinyComponentType.html#schema_Destiny-DestinyComponentType
# 100 = profile.data.userInfo
# 102 = profileInventory.data.items
# 201 = characterInventories.data[character_id].items
# 205 = characterEquipment.data[character_id].items
# 300 = itemComponents.instances
# 305 = profilePlugSets.data.plugs, characterPlugSets.data[character_id].plugs, itemComponents.sockets

# this gives us all of the information we need for vault armor for this user
profile = api.get_profile(access_token, profile_type, membership_id, [100,102,201,205,300,305,309])

os.makedirs('data', exist_ok=True)

# dump the profile out as json into the data directory
with open('data/profile.json', 'w') as file:
    json.dump(profile, file, indent=4)

print(f"Character profile loaded at:", profile["responseMintedTimestamp"])
# Out:
# Character profile loaded at: 2024-06-04T23:03:08.12Z

# %%
print("Print tree of up to second level keys in profile:")
for key in profile.keys():
    print(key)
    if isinstance(profile[key], dict):
        for subkey in profile[key].keys():
            print(f"  {subkey}")
# Out:
# Print tree of up to second level keys in profile:
# responseMintedTimestamp
# secondaryComponentsMintedTimestamp
# profileInventory
#   data
#   privacy
# profile
#   data
#   privacy
# profilePlugSets
#   data
#   privacy
# characterInventories
#   data
#   privacy
# characterEquipment
#   data
#   privacy
# characterPlugSets
#   data
#   privacy
# itemComponents
#   instances
#   sockets
#   plugObjectives

# %%
# extract all armor pieces out of the profile.  It retrieves from the vault, character inventory, and character equipment
import src.armor as armor
import pandas as pd

profile_armor = armor.ProfileArmor(profile, item_definitions, stat_definitions)

armor_dict = profile_armor.get_armor_dict()

armor_df = pd.DataFrame([{
    **vars(armor), 
    'total_stats': armor.total_stats,
    'is_exotic': armor.is_exotic,
    'class_slot': armor.class_slot
} for armor in armor_dict.values()])

armor_df
# Out:
#                 item_name   item_hash          instance_id     rarity  \
# 0    Iron Forerunner Hood  2217519207  6917529839573126708  Legendary
# 1            Grasp of Eir  3398467185  6917529814420019592  Legendary
# 2        Phoenix Protocol  4057299719  6917529106848181107     Exotic
# 3    Boots of Detestation  3702434452  6917529883188092920  Legendary
# 4       Reverie Dawn Bond  1394177923  6917529814054890031  Legendary
# ..                    ...         ...                  ...        ...
# 172        Parade Greaves  3298421491  6917530014031375339  Legendary
# 173      Greaves of Agony  3846650177  6917529874293774311  Legendary
# 174    Deep Explorer Mark   420895300  6917529837730519359  Legendary
# 175  Descending Echo Mark  3500810712  6917529559439886508  Legendary
# 176  Descending Echo Mark  3500810712  6917529613989819103  Legendary
#
#             slot  power  mobility  resilience  recovery  discipline  \
# 0         Helmet   1900         6          19         6           7
# 1      Gauntlets   1900         9          21         2          16
# 2    Chest Armor   1900        15           6         8          15
# 3      Leg Armor   1900         2          22         7          13
# 4     Class Item   1900         0           0         0           0
# ..           ...    ...       ...         ...       ...         ...
# 172    Leg Armor   1900         7          19         6          15
# 173    Leg Armor   1900         8          21         2           9
# 174   Class Item   1900         0           0         0           0
# 175   Class Item   1900         0           0         0           0
# 176   Class Item   1900         0           0         0           0
#
#      intellect  strength  is_artifice  is_masterworked d2_class  total_stats  \
# 0           12        14        False            False  Warlock           64
# 1            6        12        False             True  Warlock           66
# 2           14         2        False             True  Warlock           60
# 3           15         2        False            False  Warlock           61
# 4            0         0        False             True  Warlock            0
# ..         ...       ...          ...              ...      ...          ...
# 172          6        11        False            False    Titan           64
# 173          6        14        False             True    Titan           60
# 174          0         0         True             True    Titan            0
# 175          0         0         True             True    Titan            0
# 176          0         0         True             True    Titan            0
#
#      is_exotic           class_slot
# 0        False       Warlock Helmet
# 1        False    Warlock Gauntlets
# 2         True  Warlock Chest Armor
# 3        False    Warlock Leg Armor
# 4        False   Warlock Class Item
# ..         ...                  ...
# 172      False      Titan Leg Armor
# 173      False      Titan Leg Armor
# 174      False     Titan Class Item
# 175      False     Titan Class Item
# 176      False     Titan Class Item
#
# [177 rows x 18 columns]
