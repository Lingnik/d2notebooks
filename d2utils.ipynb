# %% [markdown]
# ## Utilities

# %%
import importlib
from src import config

client_id, api_key, _ = config.load_config()

print(f"client_id length: {len(client_id)}")
print(f"api_key length: {len(api_key)}")
# Out:
# client_id length: 5
# api_key length: 32

# %%
from src.bungie_oauth import BungieAuth
import datetime

# perform oauth login to get the access token used in later requests.  It is good for 1 hour
print("We're using a self-signed certificate to run an HTTPS server on localhost, you'll need to accept the certificate in your browser.")
access_token = BungieAuth(client_id).refresh_oauth_token()

# token is good for 1 hour, print out the time that it expires
expiration_time = datetime.datetime.now() + datetime.timedelta(hours=1)
print(f"Access token successfully acquired at: {datetime.datetime.now().isoformat()} and expires at: {expiration_time.isoformat()}")
# Out:
# We're using a self-signed certificate to run an HTTPS server on localhost, you'll need to accept the certificate in your browser.
# Please go to the following URL and authorize the app: https://www.bungie.net/en/oauth/authorize?client_id=47118&response_type=code&state=zSv_dqgFo2BN3mmq5-XEEIGpMudpSU4npE1oGxrZqU-3Sp3HeOA-E1vFDsES6eI2-UfrD_3MvCfLURJUxPPDiVFfFurkM9zxKesEUWfKYmjfCdXhEY2AIVus8tdaxjxW8-oWCWgcCiSVMeBzbEpOqJe-VbGl0k5mC3VZbAyBBOQ=&redirect_uri=https://localhost:7777/
# Stopping HTTPS server
# Access token successfully acquired at: 2024-06-14T16:21:30.230258 and expires at: 2024-06-14T17:21:30.230218

# %%
from src import bungie_api

api = bungie_api.BungieApi(client_id, api_key)
# Out:
# +bungie_manifest.BungieManifest.__init__()
# +destiny_achievement_definition.DestinyAchievementDefinition.__init__()
# +base_component.BaseManifestComponent.__init__()
# Initializing DestinyAchievementDefinition with manifest_obj: <src.bungie_manifest.BungieManifest object at 0x108ea0890>
# Manifest: {}
# -base_component.BaseManifestComponent.__init__()
# -destiny_achievement_definition.DestinyAchievementDefinition.__init__()
# -bungie_manifest.BungieManifest.__init__()

# %%
# it's nice to have all of the manifest files downloaded locally into the data directory for reference
# import shutil
# shutil.rmtree("data", ignore_errors=True)
api.manifest.cache_manifests()
# Out:
# +bungie_manifest.BungieManifest.cache_manifests()
# +bungie_api.BungieApi.request()
# Key __Platform__Destiny2__Manifest__ not in cache but on disk, caching from disk
# Requesting manifest pieces...
# Caching jsonWorldContentPaths:
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__aggregate-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths:
# Caching jsonWorldComponentContentPaths.DestinyNodeStepSummaryDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyNodeStepSummaryDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyArtDyeChannelDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyArtDyeChannelDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyArtDyeReferenceDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyArtDyeReferenceDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyPlaceDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyPlaceDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyActivityDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyActivityDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyActivityTypeDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyActivityTypeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyClassDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyClassDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyGenderDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyGenderDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyInventoryBucketDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyInventoryBucketDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyRaceDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyRaceDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyTalentGridDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyTalentGridDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyUnlockDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyUnlockDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyStatGroupDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyStatGroupDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyProgressionMappingDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyProgressionMappingDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyFactionDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyFactionDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyVendorGroupDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyVendorGroupDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyRewardSourceDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyRewardSourceDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyUnlockValueDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyUnlockValueDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyRewardMappingDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyRewardMappingDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyRewardSheetDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyRewardSheetDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyItemCategoryDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyItemCategoryDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyDamageTypeDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyDamageTypeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyActivityModeDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyActivityModeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyMedalTierDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyMedalTierDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyAchievementDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyAchievementDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyActivityGraphDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyActivityGraphDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyActivityInteractableDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyActivityInteractableDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyBondDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyBondDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyCharacterCustomizationCategoryDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyCharacterCustomizationCategoryDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyCharacterCustomizationOptionDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyCharacterCustomizationOptionDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyCollectibleDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyCollectibleDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyDestinationDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyDestinationDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyEntitlementOfferDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyEntitlementOfferDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyEquipmentSlotDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyEquipmentSlotDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyEventCardDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyEventCardDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyFireteamFinderActivityGraphDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyFireteamFinderActivityGraphDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyFireteamFinderActivitySetDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyFireteamFinderActivitySetDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyFireteamFinderLabelDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyFireteamFinderLabelDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyFireteamFinderLabelGroupDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyFireteamFinderLabelGroupDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyFireteamFinderOptionDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyFireteamFinderOptionDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyFireteamFinderOptionGroupDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyFireteamFinderOptionGroupDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyStatDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyStatDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyInventoryItemDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyInventoryItemDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyInventoryItemLiteDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyInventoryItemLiteDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyItemTierTypeDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyItemTierTypeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyLoadoutColorDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyLoadoutColorDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyLoadoutIconDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyLoadoutIconDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyLoadoutNameDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyLoadoutNameDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyLocationDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyLocationDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyLoreDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyLoreDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyMaterialRequirementSetDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyMaterialRequirementSetDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyMetricDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyMetricDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyObjectiveDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyObjectiveDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinySandboxPerkDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinySandboxPerkDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyPlatformBucketMappingDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyPlatformBucketMappingDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyPlugSetDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyPlugSetDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyPowerCapDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyPowerCapDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyPresentationNodeDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyPresentationNodeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyProgressionDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyProgressionDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyProgressionLevelRequirementDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyProgressionLevelRequirementDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyRecordDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyRecordDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyRewardAdjusterPointerDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyRewardAdjusterPointerDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyRewardAdjusterProgressionMapDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyRewardAdjusterProgressionMapDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyRewardItemListDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyRewardItemListDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinySackRewardItemListDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinySackRewardItemListDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinySandboxPatternDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinySandboxPatternDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinySeasonDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinySeasonDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinySeasonPassDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinySeasonPassDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinySocialCommendationDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinySocialCommendationDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinySocketCategoryDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinySocketCategoryDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinySocketTypeDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinySocketTypeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyTraitDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyTraitDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyUnlockCountMappingDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyUnlockCountMappingDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyUnlockEventDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyUnlockEventDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyUnlockExpressionMappingDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyUnlockExpressionMappingDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyVendorDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyVendorDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyMilestoneDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyMilestoneDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyActivityModifierDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyActivityModifierDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyReportReasonCategoryDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyReportReasonCategoryDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyArtifactDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyArtifactDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyBreakerTypeDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyBreakerTypeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyChecklistDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyChecklistDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyEnergyTypeDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyEnergyTypeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinySocialCommendationNodeDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinySocialCommendationNodeDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyGuardianRankDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyGuardianRankDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyGuardianRankConstantsDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyGuardianRankConstantsDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyLoadoutConstantsDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyLoadoutConstantsDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching jsonWorldComponentContentPaths.DestinyFireteamFinderConstantsDefinition
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__json__en__DestinyFireteamFinderConstantsDefinition-f946ef41-1dd2-49fb-bd7e-a3c45b9d20e5.json not in cache but on disk, caching from disk
# Caching mobileAssetContentPath:
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__sqlite__asset__asset_sql_content_9cc6678a20871e8f00a97d6f375383e5.content not in cache but on disk, caching from disk
# File is not JSON
# Caching mobileGearAssetDataBases:
# Version: 0, Path: /common/destiny2_content/sqlite/asset/asset_sql_content_9cc6678a20871e8f00a97d6f375383e5.content
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__sqlite__asset__asset_sql_content_9cc6678a20871e8f00a97d6f375383e5.content in cache and not expired, returning cached response
# Version: 1, Path: /common/destiny2_content/sqlite/asset/asset_sql_content_f02ae574a0bb7239607788b4de5ea7d4.content
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__sqlite__asset__asset_sql_content_f02ae574a0bb7239607788b4de5ea7d4.content not in cache but on disk, caching from disk
# File is not JSON
# Version: 2, Path: /common/destiny2_content/sqlite/asset/asset_sql_content_f02ae574a0bb7239607788b4de5ea7d4.content
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__sqlite__asset__asset_sql_content_f02ae574a0bb7239607788b4de5ea7d4.content in cache and not expired, returning cached response
# Caching mobileWorldContentPaths:
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__sqlite__en__world_sql_content_abf97b217375515297e3c59205815b37.content not in cache but on disk, caching from disk
# File is not JSON
# Caching mobileClanBannerDatabasePath
# +bungie_api.BungieApi.request()
# Key __common__destiny2_content__clanbanner__clanbanner_sql_content_27f1c484340e5614570d85c70ca83f4f.content not in cache but on disk, caching from disk
# File is not JSON
# Done caching manifests

# %%
print(len(api.manifest.destiny_achievement_definition.manifest))
# Out:
# <class 'dict'>
